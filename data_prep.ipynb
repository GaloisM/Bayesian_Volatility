# %%
import numpy as np
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
# 1024
# 1089
# 1156
# 1225
# 1296
# 1369
# 1444
# 1521
# 1600
# 1681
# 1764
# 1849
# 1936
# 2025
# 2116
# 2209
# 2304
# 2401
# 2500
# 2601
# 2704
# 2809
# 2916
# 3025
# 3136
# 3249
# 3364
# 3481
# 3600
# 3721
# 3844
# 3969
# 4096
# 4225
# 4356
# 4489
# 4624
# 4761
# 4900
# 5041
# 5184
# 5329
# 5476
# 5625
# 5776
# 5929
# 6084
# 6241
# 6400
# 6561
# 6724
# 6889
# 7056
# 7225
# 7396
# 7569
# 7744
# 7921
# 8100
# 8281
# 8464
# 8649
# 8836
# 9025
# 9216
# 9409
# 9604
# 9801

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\mateu\Bayesian_Vol\.venv-1\Scripts\python.exe

# %%
ticker = yf.Ticker("AAPL")
hist_data = ticker.history(period="1y")

# %%
x = 2*222

# %%
tickers = ["META", "AAPL", "TGT", "EXPD", "UNH", "SBUX", "ZBRA", "MRNA", "ACN", "TSN"]

data = yf.download(
    tickers,
    start="2022-01-01",
    end="2025-01-01",
    auto_adjust=True,
    group_by="ticker"
)
# Out:
# [*********************100%***********************]  10 of 10 completed

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 753 entries, 2022-01-03 to 2024-12-31
# Data columns (total 50 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   (ZBRA, Open)    753 non-null    float64
#  1   (ZBRA, High)    753 non-null    float64
#  2   (ZBRA, Low)     753 non-null    float64
#  3   (ZBRA, Close)   753 non-null    float64
#  4   (ZBRA, Volume)  753 non-null    int64
#  5   (META, Open)    753 non-null    float64
#  6   (META, High)    753 non-null    float64
#  7   (META, Low)     753 non-null    float64
#  8   (META, Close)   753 non-null    float64
#  9   (META, Volume)  753 non-null    int64
#  10  (MRNA, Open)    753 non-null    float64
#  11  (MRNA, High)    753 non-null    float64
#  12  (MRNA, Low)     753 non-null    float64
#  13  (MRNA, Close)   753 non-null    float64
#  14  (MRNA, Volume)  753 non-null    int64
#  15  (ACN, Open)     753 non-null    float64
#  16  (ACN, High)     753 non-null    float64
#  17  (ACN, Low)      753 non-null    float64
#  18  (ACN, Close)    753 non-null    float64
#  19  (ACN, Volume)   753 non-null    int64
#  20  (TGT, Open)     753 non-null    float64
#  21  (TGT, High)     753 non-null    float64
#  22  (TGT, Low)      753 non-null    float64
#  23  (TGT, Close)    753 non-null    float64
#  24  (TGT, Volume)   753 non-null    int64
#  25  (EXPD, Open)    753 non-null    float64
#  26  (EXPD, High)    753 non-null    float64
#  27  (EXPD, Low)     753 non-null    float64
#  28  (EXPD, Close)   753 non-null    float64
#  29  (EXPD, Volume)  753 non-null    int64
#  30  (UNH, Open)     753 non-null    float64
#  31  (UNH, High)     753 non-null    float64
#  32  (UNH, Low)      753 non-null    float64
#  33  (UNH, Close)    753 non-null    float64
#  34  (UNH, Volume)   753 non-null    int64
#  35  (TSN, Open)     753 non-null    float64
#  36  (TSN, High)     753 non-null    float64
#  37  (TSN, Low)      753 non-null    float64
#  38  (TSN, Close)    753 non-null    float64
#  39  (TSN, Volume)   753 non-null    int64
#  40  (AAPL, Open)    753 non-null    float64
#  41  (AAPL, High)    753 non-null    float64
#  42  (AAPL, Low)     753 non-null    float64
#  43  (AAPL, Close)   753 non-null    float64
#  44  (AAPL, Volume)  753 non-null    int64
#  45  (SBUX, Open)    753 non-null    float64
#  46  (SBUX, High)    753 non-null    float64
#  47  (SBUX, Low)     753 non-null    float64
#  48  (SBUX, Close)   753 non-null    float64
#  49  (SBUX, Volume)  753 non-null    int64
# dtypes: float64(40), int64(10)
# memory usage: 300.0 KB
